# %%
import numpy as np

# %%
data = np.load('train_toydata_color_shape_pairs.npy')

# %%
import matplotlib.pyplot as plt

# %%
data.shape
# Out:
# (10000, 2, 28, 28, 3)

# %%
fig, ax = plt.subplots(1, 2)
ax[0].imshow(data[10, 0])
ax[1].imshow(data[10, 1])

fig, ax = plt.subplots(1, 2)
ax[0].imshow(data[100, 0])
ax[1].imshow(data[100, 1])

fig, ax = plt.subplots(1, 2)
ax[0].imshow(data[2, 0])
ax[1].imshow(data[2, 1])

plt.show()
